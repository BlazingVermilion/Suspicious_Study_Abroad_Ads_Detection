# %% [markdown]
# # 01 — Collect legitimate seed posts
#
# Purpose: crawl trusted/official university and education accounts as legitimate seed data.

# %%
import os
from pathlib import Path
PROJECT_ROOT = Path.cwd().resolve()
os.environ["PROJECT_ROOT"] = str(PROJECT_ROOT)
PROJECT_ROOT

# %% [markdown]
# Run this once if you need an authenticated Instagram browser session.

# %%
# !python src/collection/save_instagram_session.py

# %% [markdown]
# Crawl legitimate seed posts into `data/raw/instagram/metadata/legitimate_seed_posts.json`.

# %%
# !python src/collection/crawl_legitimate_posts.py
