# %% [markdown]
# # 04 — Train and apply NER/RE extractor
#
# Purpose: train 5-fold DistilBERT NER/RE models, create CV metrics, and enrich silver/gold with NER/RE features.

# %%
import os
from pathlib import Path
PROJECT_ROOT = Path.cwd().resolve()
os.environ["PROJECT_ROOT"] = str(PROJECT_ROOT)

# %%
# !python src/extraction/train_ner_re_extractor.py --nerre-json data/processed/annotations/ner_re_gold_annotated_subset.json --silver-csv data/processed/splits/silver_pool.csv --binary-gold-csv data/processed/splits/binary_gold_eval.csv --out-dir data/processed/ner_re
