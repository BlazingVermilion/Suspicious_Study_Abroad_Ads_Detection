# %% [markdown]
# # 05 — Build weak labels
#
# Purpose: apply Critical Risk + Co-occurrence-based Deception Accumulation to create silver training labels.

# %%
import os
from pathlib import Path
PROJECT_ROOT = Path.cwd().resolve()
os.environ["PROJECT_ROOT"] = str(PROJECT_ROOT)

# %%
# !python src/weak_labeling/build_weak_labels.py
