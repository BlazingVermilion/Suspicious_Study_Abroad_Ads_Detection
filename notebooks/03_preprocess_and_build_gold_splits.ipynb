# %% [markdown]
# # 03 — Preprocess and build binary gold/silver split

# %%
import os
from pathlib import Path
PROJECT_ROOT = Path.cwd().resolve()
os.environ["PROJECT_ROOT"] = str(PROJECT_ROOT)

# %% [markdown]
# Normalize raw JSON metadata into the stable schema `normalized_posts.csv`.

# %%
# !python src/preprocessing/build_normalized_dataset.py --input-dir data/raw/instagram/metadata --output data/processed/normalized/normalized_posts.csv

# %% [markdown]
# Build human-verified binary gold evaluation set and silver pool. This is interactive unless `--dry-run` is used.

# %%
# !python src/annotation/build_binary_gold_split.py --normalize data/processed/normalized/normalized_posts.csv --annotation-subset data/processed/annotations/ner_re_gold_annotated_subset.json --out-dir data/processed/splits
