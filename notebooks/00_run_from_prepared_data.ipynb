# %% [markdown]
# # 00 Run from prepared data
#
# This notebook skips crawling/manual annotation and runs the full experimental pipeline from `data/prepared/`.

# %% [markdown]
# Required files: `silver_pool.csv`, `binary_gold_eval.csv`, and `ner_re_gold_annotated_subset.json`. `normalized_posts.csv` is kept for auditability.

# %%
from pathlib import Path
root = Path.cwd()
for p in [
    root/"data/prepared/normalized_posts.csv",
    root/"data/prepared/silver_pool.csv",
    root/"data/prepared/binary_gold_eval.csv",
    root/"data/prepared/ner_re_gold_annotated_subset.json",
]:
    print(p, "OK" if p.exists() else "MISSING")

# %% [markdown]
# Smoke test only. Do not report these metrics.

# %%
# !python scripts/run_prepared_data_pipeline.py --quick-test

# %% [markdown]
# Full experimental run:

# %%
# !python scripts/run_prepared_data_pipeline.py
