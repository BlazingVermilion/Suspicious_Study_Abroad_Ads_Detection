# %% [markdown]
# # 06 — Train and evaluate classifier
#
# Purpose: run baselines, ablations, DistilBERT embeddings, low-level NER/RE fusion, and gold-set evaluation.

# %%
import os
from pathlib import Path
PROJECT_ROOT = Path.cwd().resolve()
os.environ["PROJECT_ROOT"] = str(PROJECT_ROOT)

# %%
# !python src/modeling/train_classifier.py --train data/processed/weak_labeling/silver_train.csv --gold data/processed/ner_re/predictions/binary_gold_with_ner_re_ensemble.csv --output_dir outputs/classifier_evaluation
