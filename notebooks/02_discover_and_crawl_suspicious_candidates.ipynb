# %% [markdown]
# # 02 — Discover and crawl suspicious candidate posts
#
# Purpose: find study-in-Germany consulting accounts and crawl posts with suspicious-trigger filters.

# %%
import os
from pathlib import Path
PROJECT_ROOT = Path.cwd().resolve()
os.environ["PROJECT_ROOT"] = str(PROJECT_ROOT)

# %% [markdown]
# First discover candidate accounts and update `account_registry.json`.

# %%
# !python src/collection/discover_suspicious_accounts.py

# %% [markdown]
# Then crawl accounts with `posts_crawled == 0` into `suspicious_candidate_posts.json`.

# %%
# !python src/collection/crawl_suspicious_posts.py
